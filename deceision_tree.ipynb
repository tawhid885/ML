# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tree.csv")

# %%
df
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
d = {'UK':0, 'USA':1, 'N':2}
df['Nationality'] = df['Nationality'].map(d)

# %%
df
# Out:
#     Age  Experience  Rank  Nationality   Go
# 0    36          10     9            0   NO
# 1    42          12     4            1   NO
# 2    23           4     6            2   NO
# 3    52           4     4            1   NO
# 4    43          21     8            1  YES
# 5    44          14     5            0   NO
# 6    66           3     7            2  YES
# 7    35          14     9            0  YES
# 8    52          13     7            2  YES
# 9    35           5     9            2  YES
# 10   24           3     5            1   NO
# 11   18           3     7            0  YES
# 12   45           9     9            0  YES

# %%
d = {'YES':1, 'NO':0}
df['Go'] = df['Go'].map(d)

# %%
df
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            0   0
# 1    42          12     4            1   0
# 2    23           4     6            2   0
# 3    52           4     4            1   0
# 4    43          21     8            1   1
# 5    44          14     5            0   0
# 6    66           3     7            2   1
# 7    35          14     9            0   1
# 8    52          13     7            2   1
# 9    35           5     9            2   1
# 10   24           3     5            1   0
# 11   18           3     7            0   1
# 12   45           9     9            0   1

# %%
features = ['Age', 'Experience', 'Rank', 'Nationality']
X = df[features]
y = df['Go']

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(dtree, features)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tree.plot_tree(dtree, features)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
# --> 189 params = func_sig.bind(*args, **kwargs)
#     190 params.apply_defaults()
#     192 # ignore self/cls and positional/keyword markers
#
# File /usr/lib/python3.10/inspect.py:3186, in Signature.bind(self, *args, **kwargs)
#    3181 def bind(self, /, *args, **kwargs):
#    3182     """Get a BoundArguments object, that maps the passed `args`
#    3183     and `kwargs` to the function's signature.  Raises `TypeError`
#    3184     if the passed arguments can not be bound.
#    3185     """
# -> 3186     return self._bind(args, kwargs)
#
# File /usr/lib/python3.10/inspect.py:3112, in Signature._bind(self, args, kwargs, partial)
#    3108 else:
#    3109     if param.kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#    3110         # Looks like we have no parameter for this positional
#    3111         # argument
# -> 3112         raise TypeError(
#    3113             'too many positional arguments') from None
#    3115     if param.kind == _VAR_POSITIONAL:
#    3116         # We have an '*args'-like argument, let's fill it with
#    3117         # all positional arguments we have left and move on to
#    3118         # the next phase
#    3119         values = [arg_val]
#
# TypeError: too many positional arguments

# %%
tree.plot_tree(dtree, feature_names = features)
# Out:
# [Text(0.4, 0.875, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6, 0.625, 'Age <= 39.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4, 0.375, 'Age <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
dtree.predict([[40, 10, 6, 1]])
# Out:
# /home/tawhid885/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
print(dtree.predict([[40, 10, 7, 1]]))
# Out:
# [1]
# /home/tawhid885/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv("diabetes")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv("diabetes")
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'diabetes'

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df['columns']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'columns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['columns']
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'columns'

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']
X = df[features]
y = df['Outcome']

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
dtree = dtree.fit(X, y)

# %%
tree.plot_tree(dtree, feature_names = features)
# Out:
# [Text(0.48330543154761907, 0.9642857142857143, 'Glucose <= 127.5\ngini = 0.454\nsamples = 768\nvalue = [500, 268]'),
#  Text(0.19776165674603174, 0.8928571428571429, 'Age <= 28.5\ngini = 0.313\nsamples = 485\nvalue = [391, 94]'),
#  Text(0.09970238095238096, 0.8214285714285714, 'BMI <= 45.4\ngini = 0.155\nsamples = 271\nvalue = [248, 23]'),
#  Text(0.06646825396825397, 0.75, 'BMI <= 30.95\ngini = 0.139\nsamples = 267\nvalue = [247, 20]'),
#  Text(0.023809523809523808, 0.6785714285714286, 'Pregnancies <= 7.5\ngini = 0.026\nsamples = 151\nvalue = [149, 2]'),
#  Text(0.015873015873015872, 0.6071428571428571, 'DiabetesPedigreeFunction <= 0.672\ngini = 0.013\nsamples = 150\nvalue = [149, 1]'),
#  Text(0.007936507936507936, 0.5357142857142857, 'gini = 0.0\nsamples = 131\nvalue = [131, 0]'),
#  Text(0.023809523809523808, 0.5357142857142857, 'DiabetesPedigreeFunction <= 0.686\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.015873015873015872, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.031746031746031744, 0.4642857142857143, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.031746031746031744, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10912698412698413, 0.6785714285714286, 'DiabetesPedigreeFunction <= 0.501\ngini = 0.262\nsamples = 116\nvalue = [98, 18]'),
#  Text(0.07142857142857142, 0.6071428571428571, 'BloodPressure <= 53.0\ngini = 0.153\nsamples = 72\nvalue = [66, 6]'),
#  Text(0.05555555555555555, 0.5357142857142857, 'Pregnancies <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.047619047619047616, 0.4642857142857143, 'BloodPressure <= 22.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03968253968253968, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05555555555555555, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06349206349206349, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0873015873015873, 0.5357142857142857, 'Insulin <= 36.5\ngini = 0.087\nsamples = 66\nvalue = [63, 3]'),
#  Text(0.07936507936507936, 0.4642857142857143, 'Insulin <= 34.0\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.07142857142857142, 0.39285714285714285, 'BMI <= 33.65\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.06349206349206349, 0.32142857142857145, 'Glucose <= 102.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.05555555555555555, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07142857142857142, 0.25, 'Glucose <= 119.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06349206349206349, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07936507936507936, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07936507936507936, 0.32142857142857145, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.0873015873015873, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09523809523809523, 0.4642857142857143, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.14682539682539683, 0.6071428571428571, 'BloodPressure <= 69.0\ngini = 0.397\nsamples = 44\nvalue = [32, 12]'),
#  Text(0.11904761904761904, 0.5357142857142857, 'Glucose <= 88.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.1111111111111111, 0.4642857142857143, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.12698412698412698, 0.4642857142857143, 'Glucose <= 116.0\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.1111111111111111, 0.39285714285714285, 'BMI <= 32.25\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.10317460317460317, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11904761904761904, 0.32142857142857145, 'BMI <= 36.7\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.1111111111111111, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.12698412698412698, 0.25, 'BMI <= 37.4\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11904761904761904, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1349206349206349, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14285714285714285, 0.39285714285714285, 'Glucose <= 124.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1349206349206349, 0.32142857142857145, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.15079365079365079, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1746031746031746, 0.5357142857142857, 'Glucose <= 85.0\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.16666666666666666, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18253968253968253, 0.4642857142857143, 'SkinThickness <= 5.5\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.1746031746031746, 0.39285714285714285, 'BloodPressure <= 79.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.16666666666666666, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.18253968253968253, 0.32142857142857145, 'Glucose <= 104.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1746031746031746, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19047619047619047, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19047619047619047, 0.39285714285714285, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.13293650793650794, 0.75, 'BloodPressure <= 99.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.125, 0.6785714285714286, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14087301587301587, 0.6785714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29582093253968256, 0.8214285714285714, 'BMI <= 26.35\ngini = 0.443\nsamples = 214\nvalue = [143, 71]'),
#  Text(0.23412698412698413, 0.75, 'BMI <= 9.65\ngini = 0.093\nsamples = 41\nvalue = [39, 2]'),
#  Text(0.2261904761904762, 0.6785714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.24206349206349206, 0.6785714285714286, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.35751488095238093, 0.75, 'Glucose <= 99.5\ngini = 0.48\nsamples = 173\nvalue = [104, 69]'),
#  Text(0.25793650793650796, 0.6785714285714286, 'Glucose <= 28.5\ngini = 0.298\nsamples = 55\nvalue = [45, 10]'),
#  Text(0.25, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.26587301587301587, 0.6071428571428571, 'DiabetesPedigreeFunction <= 0.796\ngini = 0.256\nsamples = 53\nvalue = [45, 8]'),
#  Text(0.23015873015873015, 0.5357142857142857, 'Age <= 42.5\ngini = 0.162\nsamples = 45\nvalue = [41, 4]'),
#  Text(0.21428571428571427, 0.4642857142857143, 'DiabetesPedigreeFunction <= 0.171\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.20634920634920634, 0.39285714285714285, 'Age <= 32.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1984126984126984, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21428571428571427, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2222222222222222, 0.39285714285714285, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.24603174603174602, 0.4642857142857143, 'BMI <= 30.85\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.23809523809523808, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25396825396825395, 0.39285714285714285, 'Pregnancies <= 5.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.24603174603174602, 0.32142857142857145, 'Glucose <= 81.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.23809523809523808, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25396825396825395, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2619047619047619, 0.32142857142857145, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.30158730158730157, 0.5357142857142857, 'SkinThickness <= 35.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.29365079365079366, 0.4642857142857143, 'SkinThickness <= 20.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2857142857142857, 0.39285714285714285, 'Glucose <= 94.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2777777777777778, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29365079365079366, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30158730158730157, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.30952380952380953, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.45709325396825395, 0.6785714285714286, 'DiabetesPedigreeFunction <= 0.561\ngini = 0.5\nsamples = 118\nvalue = [59, 59]'),
#  Text(0.37450396825396826, 0.6071428571428571, 'DiabetesPedigreeFunction <= 0.2\ngini = 0.482\nsamples = 84\nvalue = [50, 34]'),
#  Text(0.3333333333333333, 0.5357142857142857, 'BMI <= 27.65\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.3253968253968254, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3412698412698413, 0.4642857142857143, 'Pregnancies <= 5.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.3333333333333333, 0.39285714285714285, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3492063492063492, 0.39285714285714285, 'BMI <= 34.55\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.3412698412698413, 0.32142857142857145, 'Insulin <= 34.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3333333333333333, 0.25, 'BMI <= 29.35\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3253968253968254, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3412698412698413, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3492063492063492, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.35714285714285715, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4156746031746032, 0.5357142857142857, 'Pregnancies <= 1.5\ngini = 0.499\nsamples = 63\nvalue = [33, 30]'),
#  Text(0.3888888888888889, 0.4642857142857143, 'Glucose <= 113.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.38095238095238093, 0.39285714285714285, 'BMI <= 36.15\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.373015873015873, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3888888888888889, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3968253968253968, 0.39285714285714285, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.44246031746031744, 0.4642857142857143, 'BloodPressure <= 67.0\ngini = 0.482\nsamples = 52\nvalue = [31, 21]'),
#  Text(0.4126984126984127, 0.39285714285714285, 'DiabetesPedigreeFunction <= 0.362\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.40476190476190477, 0.32142857142857145, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.42063492063492064, 0.32142857142857145, 'BMI <= 30.05\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4126984126984127, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.42857142857142855, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4722222222222222, 0.39285714285714285, 'BMI <= 34.45\ngini = 0.42\nsamples = 40\nvalue = [28, 12]'),
#  Text(0.4523809523809524, 0.32142857142857145, 'BloodPressure <= 83.0\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.4444444444444444, 0.25, 'Glucose <= 120.0\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.42857142857142855, 0.17857142857142858, 'DiabetesPedigreeFunction <= 0.252\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.42063492063492064, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4365079365079365, 0.10714285714285714, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4603174603174603, 0.17857142857142858, 'DiabetesPedigreeFunction <= 0.239\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.4523809523809524, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.46825396825396826, 0.10714285714285714, 'Age <= 30.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4603174603174603, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47619047619047616, 0.03571428571428571, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.4603174603174603, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.49206349206349204, 0.32142857142857145, 'BMI <= 43.1\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.48412698412698413, 0.25, 'Glucose <= 101.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.47619047619047616, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.49206349206349204, 0.17857142857142858, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.5, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5396825396825397, 0.6071428571428571, 'Pregnancies <= 6.5\ngini = 0.389\nsamples = 34\nvalue = [9, 25]'),
#  Text(0.5317460317460317, 0.5357142857142857, 'Insulin <= 120.5\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.5079365079365079, 0.4642857142857143, 'Age <= 34.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.5, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5158730158730159, 0.39285714285714285, 'BMI <= 33.15\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.5079365079365079, 0.32142857142857145, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5238095238095238, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5555555555555556, 0.4642857142857143, 'SkinThickness <= 47.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.5476190476190477, 0.39285714285714285, 'Insulin <= 225.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.5396825396825397, 0.32142857142857145, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5555555555555556, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5634920634920635, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5476190476190477, 0.5357142857142857, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.7688492063492064, 0.8928571428571429, 'BMI <= 29.95\ngini = 0.474\nsamples = 283\nvalue = [109, 174]'),
#  Text(0.6587301587301587, 0.8214285714285714, 'Glucose <= 145.5\ngini = 0.432\nsamples = 76\nvalue = [52, 24]'),
#  Text(0.626984126984127, 0.75, 'Insulin <= 132.5\ngini = 0.25\nsamples = 41\nvalue = [35, 6]'),
#  Text(0.6190476190476191, 0.6785714285714286, 'BMI <= 28.15\ngini = 0.337\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.6031746031746031, 0.6071428571428571, 'BloodPressure <= 73.0\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.5952380952380952, 0.5357142857142857, 'BloodPressure <= 71.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.5873015873015873, 0.4642857142857143, 'Glucose <= 129.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.5793650793650794, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5952380952380952, 0.39285714285714285, 'Glucose <= 138.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.5873015873015873, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6031746031746031, 0.32142857142857145, 'SkinThickness <= 17.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5952380952380952, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6111111111111112, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6031746031746031, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6111111111111112, 0.5357142857142857, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.6349206349206349, 0.6071428571428571, 'Glucose <= 135.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.626984126984127, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6428571428571429, 0.5357142857142857, 'Pregnancies <= 9.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6349206349206349, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6507936507936508, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6349206349206349, 0.6785714285714286, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6904761904761905, 0.75, 'Age <= 25.5\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.6825396825396826, 0.6785714285714286, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6984126984126984, 0.6785714285714286, 'Age <= 61.0\ngini = 0.487\nsamples = 31\nvalue = [13, 18]'),
#  Text(0.6904761904761905, 0.6071428571428571, 'BMI <= 27.1\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(0.6746031746031746, 0.5357142857142857, 'Glucose <= 151.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.6666666666666666, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6825396825396826, 0.4642857142857143, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.7063492063492064, 0.5357142857142857, 'BloodPressure <= 82.0\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.6984126984126984, 0.4642857142857143, 'DiabetesPedigreeFunction <= 0.397\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.6904761904761905, 0.39285714285714285, 'Pregnancies <= 6.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.6825396825396826, 0.32142857142857145, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6984126984126984, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7063492063492064, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7142857142857143, 0.4642857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7063492063492064, 0.6071428571428571, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.878968253968254, 0.8214285714285714, 'Glucose <= 157.5\ngini = 0.399\nsamples = 207\nvalue = [57, 150]'),
#  Text(0.7956349206349206, 0.75, 'Age <= 30.5\ngini = 0.476\nsamples = 115\nvalue = [45, 70]'),
#  Text(0.753968253968254, 0.6785714285714286, 'BloodPressure <= 61.0\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.746031746031746, 0.6071428571428571, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.7619047619047619, 0.6071428571428571, 'BMI <= 41.8\ngini = 0.439\nsamples = 40\nvalue = [27, 13]'),
#  Text(0.746031746031746, 0.5357142857142857, 'DiabetesPedigreeFunction <= 1.141\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.7380952380952381, 0.4642857142857143, 'Pregnancies <= 4.5\ngini = 0.285\nsamples = 29\nvalue = [24, 5]'),
#  Text(0.7222222222222222, 0.39285714285714285, 'BloodPressure <= 73.0\ngini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.7142857142857143, 0.32142857142857145, 'Pregnancies <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6984126984126984, 0.25, 'DiabetesPedigreeFunction <= 0.183\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6904761904761905, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7063492063492064, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7301587301587301, 0.25, 'BloodPressure <= 71.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.7222222222222222, 0.17857142857142858, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7380952380952381, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7301587301587301, 0.32142857142857145, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.753968253968254, 0.39285714285714285, 'BloodPressure <= 66.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.746031746031746, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7619047619047619, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.753968253968254, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7777777777777778, 0.5357142857142857, 'DiabetesPedigreeFunction <= 0.373\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.7698412698412699, 0.4642857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7857142857142857, 0.4642857142857143, 'Glucose <= 142.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.7777777777777778, 0.39285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7936507936507936, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8373015873015873, 0.6785714285714286, 'DiabetesPedigreeFunction <= 0.429\ngini = 0.4\nsamples = 65\nvalue = [18, 47]'),
#  Text(0.8174603174603174, 0.6071428571428571, 'BMI <= 45.55\ngini = 0.497\nsamples = 28\nvalue = [13, 15]'),
#  Text(0.8095238095238095, 0.5357142857142857, 'DiabetesPedigreeFunction <= 0.136\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.8015873015873016, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8174603174603174, 0.4642857142857143, 'BMI <= 32.45\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.8095238095238095, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8253968253968254, 0.39285714285714285, 'Glucose <= 130.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.8174603174603174, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8333333333333334, 0.32142857142857145, 'Glucose <= 137.0\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.8253968253968254, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8412698412698413, 0.25, 'Age <= 42.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.8333333333333334, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8492063492063492, 0.17857142857142858, 'DiabetesPedigreeFunction <= 0.226\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.8412698412698413, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8571428571428571, 0.10714285714285714, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8253968253968254, 0.5357142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8571428571428571, 0.6071428571428571, 'Insulin <= 333.5\ngini = 0.234\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.8412698412698413, 0.5357142857142857, 'BMI <= 40.05\ngini = 0.161\nsamples = 34\nvalue = [3, 31]'),
#  Text(0.8333333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.8492063492063492, 0.4642857142857143, 'BMI <= 40.9\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.8412698412698413, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8571428571428571, 0.39285714285714285, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.873015873015873, 0.5357142857142857, 'Age <= 44.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8650793650793651, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8809523809523809, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9623015873015873, 0.75, 'Insulin <= 629.5\ngini = 0.227\nsamples = 92\nvalue = [12, 80]'),
#  Text(0.9404761904761905, 0.6785714285714286, 'DiabetesPedigreeFunction <= 0.3\ngini = 0.199\nsamples = 89\nvalue = [10, 79]'),
#  Text(0.9206349206349206, 0.6071428571428571, 'DiabetesPedigreeFunction <= 0.288\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text(0.9126984126984127, 0.5357142857142857, 'Age <= 37.5\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.8968253968253969, 0.4642857142857143, 'BMI <= 45.6\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.8888888888888888, 0.39285714285714285, 'Insulin <= 87.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.8809523809523809, 0.32142857142857145, 'Age <= 25.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.873015873015873, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8888888888888888, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8968253968253969, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9047619047619048, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9285714285714286, 0.4642857142857143, 'Age <= 56.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.9206349206349206, 0.39285714285714285, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.9365079365079365, 0.39285714285714285, 'Age <= 63.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9285714285714286, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9444444444444444, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9285714285714286, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9603174603174603, 0.6071428571428571, 'Age <= 44.0\ngini = 0.117\nsamples = 64\nvalue = [4, 60]'),
#  Text(0.9523809523809523, 0.5357142857142857, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.9682539682539683, 0.5357142857142857, 'Pregnancies <= 6.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.9603174603174603, 0.4642857142857143, 'Age <= 51.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.9523809523809523, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9682539682539683, 0.39285714285714285, 'DiabetesPedigreeFunction <= 1.157\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.9603174603174603, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9761904761904762, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9761904761904762, 0.4642857142857143, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9841269841269841, 0.6785714285714286, 'DiabetesPedigreeFunction <= 0.412\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9761904761904762, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9920634920634921, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]
