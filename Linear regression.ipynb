# %%
import matplotlib.pyplot as plt

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Linear regression

# %%
from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(x, y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from scipy import stats
#       2 slope, intercept, r, p, std_err = stats.linregress(x, y)
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting numpy<1.28.0,>=1.21.6
#   Using cached numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy, scipy
# Successfully installed numpy-1.25.2 scipy-1.11.2

# %%
from scipy import stats
slope, intercept, r, p std_err = stats.linregress(x, y)
# Out:
#   Cell In[6], line 2
#     slope, intercept, r, p std_err = stats.linregress(x, y)
#                            ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(x, y)
# Out:
# /home/tawhid885/.local/lib/python3.10/site-packages/scipy/__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/tawhid885/.local/lib/python3.10/site-packages (1.25.2)

# %%
print(slope)
# Out:
# -1.751287711552612

# %%
print(stats.linregress(x, y))
# Out:
# LinregressResult(slope=-1.751287711552612, intercept=103.10596026490066, rvalue=-0.7585915243761551, pvalue=0.002646873922456101, stderr=0.45353615760774196, intercept_stderr=3.903492810154512)

# %%
print(type(stats.linregress(x, y)))
# Out:
# <class 'scipy.stats._stats_mstats_common.LinregressResult'>

# %%
def my_function(x):
    return slope * x + intercept

# %%
mymodel = list(map(my_function, x))

# %%
mymodel
# Out:
# [94.3495217071376,
#  90.84694628403237,
#  89.09565857247976,
#  90.84694628403237,
#  99.60338484179543,
#  73.33406916850626,
#  99.60338484179543,
#  87.34437086092716,
#  96.1008094186902,
#  83.84179543782193,
#  82.09050772626932,
#  87.34437086092716,
#  92.59823399558499]

# %%
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
speed = my_function(10)

# %%
speed
# Out:
# 85.59308314937454

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
my_model = list(map(my_function, x))

# %%
my_model
# Out:
# [41.690858573398735,
#  41.050695829069916,
#  40.95327975928075,
#  40.95327975928075,
#  41.77435806178946,
#  40.59144864292098,
#  41.370777201234326,
#  40.925446596483845,
#  40.981112922077656,
#  40.730614456905506,
#  40.81411394529622,
#  40.85586368949158,
#  41.12027873606218,
#  41.34294403843742,
#  40.53578231732717,
#  40.52186573592872,
#  40.95327975928075,
#  41.370777201234326,
#  41.45427668962504,
#  41.00894608487456]

# %%
print(r)
# Out:
# 0.013318141542974908

# %%
plt.scatter(x, y)
