# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.random.seed(4)

# %%
x = np.random.normal(3, 1, 100)

# %%
x
# Out:
# array([3.05056171, 3.49995133, 2.00409107, 3.69359851, 2.58169848,
#        1.41542276, 2.35229323, 3.59857517, 3.33225003, 1.85252337,
#        3.61866969, 2.91201307, 3.4250724 , 3.33225315, 1.84318374,
#        3.35099715, 2.39311272, 4.54697933, 3.72334161, 3.04613557,
#        2.01700835, 3.05443274, 3.15989294, 1.79105184, 5.22336022,
#        3.39429521, 4.69235772, 1.88718785, 4.63574754, 1.63903441,
#        2.34877417, 3.54245131, 3.04800625, 0.64192637, 1.89441596,
#        3.83783635, 5.08787087, 3.91484096, 2.72379665, 3.7965119 ,
#        1.85620143, 3.50991978, 1.6525397 , 2.9906399 , 2.86929536,
#        3.80208661, 2.69703603, 4.20200259, 2.80325472, 3.8365287 ,
#        3.78660228, 1.15912413, 3.03754749, 3.03592805, 2.22126008,
#        3.17941071, 1.54446567, 3.55618522, 3.50977885, 3.30044554,
#        5.47658416, 3.3523434 , 3.067471  , 2.2677353 , 3.29714121,
#        2.0382232 , 4.27181862, 2.35235547, 3.15846954, 4.99008302,
#        4.16418756, 3.24266016, 4.3799201 , 2.94544129, 3.79523395,
#        3.01908996, 2.09456186, 3.43027133, 3.93465006, 2.65389813,
#        1.90287812, 2.47180393, 0.62022473, 2.39231631, 1.92470991,
#        5.02240507, 2.4351247 , 1.45707095, 3.87084178, 2.82478947,
#        3.04860301, 3.1886462 , 3.20931349, 2.62555508, 3.9546986 ,
#        3.52324766, 2.50418148, 2.82853539, 2.0556314 , 3.28086468])

# %%
y = np.random.normal(150, 40, 100)/x

# %%
plt.scatter(x, y)
plt.show()

# %%
train_x = x[0:80]
train_y = y[80:]

# %%
train_x = x[]
train_y = y[:80]
# Out:
#   Cell In[9], line 1
#     train_x = x[]
#                 ^
# SyntaxError: invalid syntax

# %%
train_x = x[:80]
train_y = y[:80]
test_x = x[80:]
test_y = y[80:]

# %%
plt.scatter(train_x, train_y)
plt.show()

# %%
plt.scatter(test_x, test_y)
plt.show()

# %%
mymodel = np.poly1d(np.polyfit(train_x, train_y, 4))

# %%
data = np.linspace(0, 6, 100)

# %%
plt.scatter(train_x, train_y)
plt.plot(data, mymodel(data))
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2 = re_score(train_y, mymodel(train_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 r2 = re_score(train_y, mymodel(train_x))
#
# NameError: name 're_score' is not defined

# %%
r2 = r2_score(train_y, mymodel(train_x))

# %%
r2
# Out:
# 0.6836277431245419

# %%
test_r2 = re_score(test_y, momodel(test_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 test_r2 = re_score(test_y, momodel(test_x))
#
# NameError: name 're_score' is not defined

# %%
test_r2 = r2_score(test_y, mymodel(test_x))

# %%
test_r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 test_r
#
# NameError: name 'test_r' is not defined

# %%
test_r2
# Out:
# 0.812978621068844

# %%
print(mymodel(5))
# Out:
# 30.17422093208549
